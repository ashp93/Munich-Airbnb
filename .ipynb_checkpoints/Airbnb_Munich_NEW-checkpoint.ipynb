# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno

# %%
calendar_df = pd.read_csv('calendar.zip')
print(calendar_df.shape)
listings_df = pd.read_csv('listings.zip')
print(listings_df.shape)
reviews_df = pd.read_csv('reviews.zip')
print(reviews_df.shape)
# Out:
# (4190565, 7)
# I:\Python\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (43,61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (11481, 106)
# (175562, 6)

# %% [markdown]
# # Focus on listings_df first
# listings_df contains columns with incorrect data types

# %%
listings_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11481 entries, 0 to 11480
# Data columns (total 106 columns):
# id                                              int64
# listing_url                                     object
# scrape_id                                       int64
# last_scraped                                    object
# name                                            object
# summary                                         object
# space                                           object
# description                                     object
# experiences_offered                             object
# neighborhood_overview                           object
# notes                                           object
# transit                                         object
# access                                          object
# interaction                                     object
# house_rules                                     object
# thumbnail_url                                   float64
# medium_url                                      float64
# picture_url                                     object
# xl_picture_url                                  float64
# host_id                                         int64
# host_url                                        object
# host_name                                       object
# host_since                                      object
# host_location                                   object
# host_about                                      object
# host_response_time                              object
# host_response_rate                              object
# host_acceptance_rate                            float64
# host_is_superhost                               object
# host_thumbnail_url                              object
# host_picture_url                                object
# host_neighbourhood                              object
# host_listings_count                             float64
# host_total_listings_count                       float64
# host_verifications                              object
# host_has_profile_pic                            object
# host_identity_verified                          object
# street                                          object
# neighbourhood                                   object
# neighbourhood_cleansed                          object
# neighbourhood_group_cleansed                    float64
# city                                            object
# state                                           object
# zipcode                                         object
# market                                          object
# smart_location                                  object
# country_code                                    object
# country                                         object
# latitude                                        float64
# longitude                                       float64
# is_location_exact                               object
# property_type                                   object
# room_type                                       object
# accommodates                                    int64
# bathrooms                                       float64
# bedrooms                                        float64
# beds                                            float64
# bed_type                                        object
# amenities                                       object
# square_feet                                     float64
# price                                           object
# weekly_price                                    object
# monthly_price                                   object
# security_deposit                                object
# cleaning_fee                                    object
# guests_included                                 int64
# extra_people                                    object
# minimum_nights                                  int64
# maximum_nights                                  int64
# minimum_minimum_nights                          int64
# maximum_minimum_nights                          int64
# minimum_maximum_nights                          int64
# maximum_maximum_nights                          int64
# minimum_nights_avg_ntm                          float64
# maximum_nights_avg_ntm                          float64
# calendar_updated                                object
# has_availability                                object
# availability_30                                 int64
# availability_60                                 int64
# availability_90                                 int64
# availability_365                                int64
# calendar_last_scraped                           object
# number_of_reviews                               int64
# number_of_reviews_ltm                           int64
# first_review                                    object
# last_review                                     object
# review_scores_rating                            float64
# review_scores_accuracy                          float64
# review_scores_cleanliness                       float64
# review_scores_checkin                           float64
# review_scores_communication                     float64
# review_scores_location                          float64
# review_scores_value                             float64
# requires_license                                object
# license                                         object
# jurisdiction_names                              float64
# instant_bookable                                object
# is_business_travel_ready                        object
# cancellation_policy                             object
# require_guest_profile_picture                   object
# require_guest_phone_verification                object
# calculated_host_listings_count                  int64
# calculated_host_listings_count_entire_homes     int64
# calculated_host_listings_count_private_rooms    int64
# calculated_host_listings_count_shared_rooms     int64
# reviews_per_month                               float64
# dtypes: float64(24), int64(21), object(61)
# memory usage: 9.3+ MB

# %% [markdown]
# There are too many columns, let's eliminate the ones that don't look helpful.
# First we'll narrow it down by removing the ones with too many missing values.

# %%
listings_df.isnull().mean()>.5
# Out:
# id                                              False
# listing_url                                     False
# scrape_id                                       False
# last_scraped                                    False
# name                                            False
#                                                 ...
# calculated_host_listings_count                  False
# calculated_host_listings_count_entire_homes     False
# calculated_host_listings_count_private_rooms    False
# calculated_host_listings_count_shared_rooms     False
# reviews_per_month                               False
# Length: 106, dtype: bool

# %%
#We'll drop these ones
listings_df.isnull().mean()[lambda x : x>.5]
# Out:
# notes                           0.710043
# access                          0.559185
# house_rules                     0.516157
# thumbnail_url                   1.000000
# medium_url                      1.000000
# xl_picture_url                  1.000000
# host_about                      0.563540
# host_acceptance_rate            1.000000
# neighbourhood_group_cleansed    1.000000
# square_feet                     0.985454
# weekly_price                    0.903406
# monthly_price                   0.937288
# license                         0.999652
# jurisdiction_names              1.000000
# dtype: float64

# %%
listings_df = listings_df.drop(listings_df.isnull().mean()[lambda x : x>.5].index, axis=1)

# %%
listings_df
# Out:
#              id                            listing_url       scrape_id  \
# 0         36720     https://www.airbnb.com/rooms/36720  20191125094942
# 1         97945     https://www.airbnb.com/rooms/97945  20191125094942
# 2        114695    https://www.airbnb.com/rooms/114695  20191125094942
# 3        127383    https://www.airbnb.com/rooms/127383  20191125094942
# 4        157808    https://www.airbnb.com/rooms/157808  20191125094942
# ...         ...                                    ...             ...
# 11476  40342200  https://www.airbnb.com/rooms/40342200  20191125094942
# 11477  40343877  https://www.airbnb.com/rooms/40343877  20191125094942
# 11478  40344151  https://www.airbnb.com/rooms/40344151  20191125094942
# 11479  40347084  https://www.airbnb.com/rooms/40347084  20191125094942
# 11480  40354205  https://www.airbnb.com/rooms/40354205  20191125094942
#
#       last_scraped                                           name  \
# 0       2019-11-25            Beautiful 2 rooms flat, Glockenbach
# 1       2019-11-25               Deluxw-Apartm. with roof terrace
# 2       2019-11-25             Apartment Munich/East with sundeck
# 3       2019-11-25              City apartment next to Pinakothek
# 4       2019-11-25                    Near Olympia,English Garden
# ...            ...                                            ...
# 11476   2019-11-25  Charmante Altbauwohnung im Herzen von München
# 11477   2019-11-25             Central apartment near the Bavaria
# 11478   2019-11-25                                   Room in Laim
# 11479   2019-11-25          Neuhausen mit persönlichem Ambiente !
# 11480   2019-11-25             Private Room Historic Heart Munich
#
#                                                  summary  \
# 0      Very quiet, yet centrally located 2 rooms apt....
# 1                                                    NaN
# 2                                                    NaN
# 3      Die Wohnung hat 55 qm und ist voll ausgestatte...
# 4      Kleines gemütliches Privat Zimmer mit Kabel TV...
# ...                                                  ...
# 11476  Sehr charmante, helle Altbauwohnung im Herzen ...
# 11477  Big living room with large living room table, ...
# 11478  The apartment is in Laim. Bus stop and a tram ...
# 11479  Sie sind eingeladen, meine Wohnung (wunderbar ...
# 11480  Private room in newly renovated 3-bdr loft in ...
#
#                                                    space  \
# 0      2-Zimmer Altbauwohung Beste Lage, zentral, im ...
# 1      We offer a modern, quiet apartment with a sunn...
# 2      It´s a quiet and sunny apartment close to the ...
# 3      My cosy apartment is located in the heart of M...
# 4      Kleines gemütliches Privat Zimmer ca.14qm möbl...
# ...                                                  ...
# 11476                                                NaN
# 11477                                                NaN
# 11478                                                NaN
# 11479                                                NaN
# 11480  Beautifully decorated this loft excites with a...
#
#                                              description experiences_offered  \
# 0      Very quiet, yet centrally located 2 rooms apt....                none
# 1      We offer a modern, quiet apartment with a sunn...                none
# 2      It´s a quiet and sunny apartment close to the ...                none
# 3      My cosy apartment is located in the heart of M...                none
# 4      Kleines gemütliches Privat Zimmer ca.14qm möbl...                none
# ...                                                  ...                 ...
# 11476  Sehr charmante, helle Altbauwohnung im Herzen ...                none
# 11477  Big living room with large living room table, ...                none
# 11478  The apartment is in Laim. Bus stop and a tram ...                none
# 11479  Sie sind eingeladen, meine Wohnung (wunderbar ...                none
# 11480  Private room in newly renovated 3-bdr loft in ...                none
#
#                                    neighborhood_overview  ...  \
# 0      Glockenbachviertel area has the hippest restau...  ...
# 1      We are living in a outskirt of Munich its call...  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4      In der Nähe befinden sich einige Kaffees,Kneip...  ...
# ...                                                  ...  ...
# 11476  Ruhiges Bewohnerviertel ohne Durchgangsverkehr...  ...
# 11477                                                NaN  ...
# 11478                                                NaN  ...
# 11479                                                NaN  ...
# 11480  You are in the heart of Munich. Just around th...  ...
#
#       instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                    f                        f  strict_14_with_grace_period
# 1                    f                        f                     flexible
# 2                    f                        f  strict_14_with_grace_period
# 3                    f                        f                     flexible
# 4                    f                        f                     moderate
# ...                ...                      ...                          ...
# 11476                f                        f                     moderate
# 11477                f                        f                     flexible
# 11478                f                        f                     flexible
# 11479                f                        f                     moderate
# 11480                f                        f  strict_14_with_grace_period
#
#        require_guest_profile_picture require_guest_phone_verification  \
# 0                                  f                                f
# 1                                  f                                f
# 2                                  f                                f
# 3                                  t                                f
# 4                                  f                                f
# ...                              ...                              ...
# 11476                              f                                f
# 11477                              f                                f
# 11478                              f                                f
# 11479                              f                                f
# 11480                              f                                f
#
#       calculated_host_listings_count  \
# 0                                  1
# 1                                  1
# 2                                  2
# 3                                  2
# 4                                  1
# ...                              ...
# 11476                              1
# 11477                              4
# 11478                              1
# 11479                              1
# 11480                              4
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               1
# 2                                               2
# 3                                               1
# 4                                               0
# ...                                           ...
# 11476                                           1
# 11477                                           1
# 11478                                           0
# 11479                                           1
# 11480                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                1
# 4                                                1
# ...                                            ...
# 11476                                            0
# 11477                                            3
# 11478                                            1
# 11479                                            0
# 11480                                            3
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.37
# 1                                               0              1.32
# 2                                               0              0.52
# 3                                               0              0.79
# 4                                               0               NaN
# ...                                           ...               ...
# 11476                                           0               NaN
# 11477                                           0               NaN
# 11478                                           0               NaN
# 11479                                           0               NaN
# 11480                                           0               NaN
#
# [11481 rows x 92 columns]

# %%
listings_df[listings_df.columns[listings_df.columns.str.contains('review')]].query('review_scores_cleanliness < 10')
# Out:
#        number_of_reviews  number_of_reviews_ltm first_review last_review  \
# 5                     31                      4   2011-08-15  2019-09-29
# 7                     61                      3   2011-08-31  2019-11-13
# 11                    65                     10   2011-07-31  2019-11-02
# 12                   234                     88   2011-10-02  2019-11-08
# 14                    32                      8   2011-09-26  2019-10-08
# ...                  ...                    ...          ...         ...
# 11243                  2                      2   2019-11-14  2019-11-20
# 11247                  2                      2   2019-11-10  2019-11-13
# 11312                  1                      1   2019-11-11  2019-11-11
# 11331                  1                      1   2019-11-16  2019-11-16
# 11336                  1                      1   2019-11-21  2019-11-21
#
#        review_scores_rating  review_scores_accuracy  \
# 5                      93.0                     9.0
# 7                      91.0                     9.0
# 11                     94.0                    10.0
# 12                     98.0                     9.0
# 14                     97.0                    10.0
# ...                     ...                     ...
# 11243                 100.0                    10.0
# 11247                  90.0                    10.0
# 11312                  80.0                    10.0
# 11331                 100.0                    10.0
# 11336                 100.0                    10.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# 5                            9.0                    9.0
# 7                            9.0                   10.0
# 11                           9.0                   10.0
# 12                           9.0                   10.0
# 14                           9.0                   10.0
# ...                          ...                    ...
# 11243                        9.0                   10.0
# 11247                        9.0                   10.0
# 11312                        8.0                   10.0
# 11331                        6.0                   10.0
# 11336                        8.0                   10.0
#
#        review_scores_communication  review_scores_location  \
# 5                             10.0                     9.0
# 7                             10.0                     9.0
# 11                            10.0                    10.0
# 12                            10.0                    10.0
# 14                            10.0                    10.0
# ...                            ...                     ...
# 11243                         10.0                     9.0
# 11247                         10.0                    10.0
# 11312                         10.0                     8.0
# 11331                         10.0                    10.0
# 11336                         10.0                    10.0
#
#        review_scores_value  reviews_per_month
# 5                      9.0               0.31
# 7                      9.0               0.61
# 11                    10.0               0.64
# 12                    10.0               2.36
# 14                     9.0               0.32
# ...                    ...                ...
# 11243                 10.0               2.00
# 11247                  9.0               2.00
# 11312                  8.0               1.00
# 11331                  8.0               1.00
# 11336                 10.0               1.00
#
# [2982 rows x 12 columns]

# %%
listings_df[listings_df.columns[listings_df.columns.str.contains('review')]]['review_scores_cleanliness'].value_counts()
# Out:
# 10.0    5757
# 9.0     1957
# 8.0      709
# 7.0      121
# 6.0      118
# 4.0       29
# 2.0       24
# 5.0       22
# 3.0        2
# Name: review_scores_cleanliness, dtype: int64

# %%
listings_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11481 entries, 0 to 11480
# Data columns (total 92 columns):
# id                                              11481 non-null int64
# listing_url                                     11481 non-null object
# scrape_id                                       11481 non-null int64
# last_scraped                                    11481 non-null object
# name                                            11459 non-null object
# summary                                         10863 non-null object
# space                                           7197 non-null object
# description                                     11178 non-null object
# experiences_offered                             11481 non-null object
# neighborhood_overview                           6151 non-null object
# transit                                         7139 non-null object
# interaction                                     5826 non-null object
# picture_url                                     11481 non-null object
# host_id                                         11481 non-null int64
# host_url                                        11481 non-null object
# host_name                                       11458 non-null object
# host_since                                      11458 non-null object
# host_location                                   11411 non-null object
# host_response_time                              6377 non-null object
# host_response_rate                              6377 non-null object
# host_is_superhost                               11458 non-null object
# host_thumbnail_url                              11458 non-null object
# host_picture_url                                11458 non-null object
# host_neighbourhood                              8739 non-null object
# host_listings_count                             11458 non-null float64
# host_total_listings_count                       11458 non-null float64
# host_verifications                              11481 non-null object
# host_has_profile_pic                            11458 non-null object
# host_identity_verified                          11458 non-null object
# street                                          11481 non-null object
# neighbourhood                                   11479 non-null object
# neighbourhood_cleansed                          11481 non-null object
# city                                            11481 non-null object
# state                                           11416 non-null object
# zipcode                                         11225 non-null object
# market                                          11467 non-null object
# smart_location                                  11481 non-null object
# country_code                                    11481 non-null object
# country                                         11481 non-null object
# latitude                                        11481 non-null float64
# longitude                                       11481 non-null float64
# is_location_exact                               11481 non-null object
# property_type                                   11481 non-null object
# room_type                                       11481 non-null object
# accommodates                                    11481 non-null int64
# bathrooms                                       11460 non-null float64
# bedrooms                                        11451 non-null float64
# beds                                            11463 non-null float64
# bed_type                                        11481 non-null object
# amenities                                       11481 non-null object
# price                                           11481 non-null object
# security_deposit                                7201 non-null object
# cleaning_fee                                    7914 non-null object
# guests_included                                 11481 non-null int64
# extra_people                                    11481 non-null object
# minimum_nights                                  11481 non-null int64
# maximum_nights                                  11481 non-null int64
# minimum_minimum_nights                          11481 non-null int64
# maximum_minimum_nights                          11481 non-null int64
# minimum_maximum_nights                          11481 non-null int64
# maximum_maximum_nights                          11481 non-null int64
# minimum_nights_avg_ntm                          11481 non-null float64
# maximum_nights_avg_ntm                          11481 non-null float64
# calendar_updated                                11481 non-null object
# has_availability                                11481 non-null object
# availability_30                                 11481 non-null int64
# availability_60                                 11481 non-null int64
# availability_90                                 11481 non-null int64
# availability_365                                11481 non-null int64
# calendar_last_scraped                           11481 non-null object
# number_of_reviews                               11481 non-null int64
# number_of_reviews_ltm                           11481 non-null int64
# first_review                                    8927 non-null object
# last_review                                     8927 non-null object
# review_scores_rating                            8747 non-null float64
# review_scores_accuracy                          8735 non-null float64
# review_scores_cleanliness                       8739 non-null float64
# review_scores_checkin                           8733 non-null float64
# review_scores_communication                     8738 non-null float64
# review_scores_location                          8735 non-null float64
# review_scores_value                             8733 non-null float64
# requires_license                                11481 non-null object
# instant_bookable                                11481 non-null object
# is_business_travel_ready                        11481 non-null object
# cancellation_policy                             11481 non-null object
# require_guest_profile_picture                   11481 non-null object
# require_guest_phone_verification                11481 non-null object
# calculated_host_listings_count                  11481 non-null int64
# calculated_host_listings_count_entire_homes     11481 non-null int64
# calculated_host_listings_count_private_rooms    11481 non-null int64
# calculated_host_listings_count_shared_rooms     11481 non-null int64
# reviews_per_month                               8927 non-null float64
# dtypes: float64(17), int64(21), object(54)
# memory usage: 8.1+ MB

# %%
listings_df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   36720   https://www.airbnb.com/rooms/36720  20191125094942   2019-11-25
# 1   97945   https://www.airbnb.com/rooms/97945  20191125094942   2019-11-25
# 2  114695  https://www.airbnb.com/rooms/114695  20191125094942   2019-11-25
# 3  127383  https://www.airbnb.com/rooms/127383  20191125094942   2019-11-25
# 4  157808  https://www.airbnb.com/rooms/157808  20191125094942   2019-11-25
#
#                                   name  \
# 0  Beautiful 2 rooms flat, Glockenbach
# 1     Deluxw-Apartm. with roof terrace
# 2   Apartment Munich/East with sundeck
# 3    City apartment next to Pinakothek
# 4          Near Olympia,English Garden
#
#                                              summary  \
# 0  Very quiet, yet centrally located 2 rooms apt....
# 1                                                NaN
# 2                                                NaN
# 3  Die Wohnung hat 55 qm und ist voll ausgestatte...
# 4  Kleines gemütliches Privat Zimmer mit Kabel TV...
#
#                                                space  \
# 0  2-Zimmer Altbauwohung Beste Lage, zentral, im ...
# 1  We offer a modern, quiet apartment with a sunn...
# 2  It´s a quiet and sunny apartment close to the ...
# 3  My cosy apartment is located in the heart of M...
# 4  Kleines gemütliches Privat Zimmer ca.14qm möbl...
#
#                                          description experiences_offered  \
# 0  Very quiet, yet centrally located 2 rooms apt....                none
# 1  We offer a modern, quiet apartment with a sunn...                none
# 2  It´s a quiet and sunny apartment close to the ...                none
# 3  My cosy apartment is located in the heart of M...                none
# 4  Kleines gemütliches Privat Zimmer ca.14qm möbl...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  Glockenbachviertel area has the hippest restau...  ...                f
# 1  We are living in a outskirt of Munich its call...  ...                f
# 2                                                NaN  ...                f
# 3                                                NaN  ...                f
# 4  In der Nähe befinden sich einige Kaffees,Kneip...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f                     flexible
# 4                        f                     moderate
#
#    require_guest_profile_picture require_guest_phone_verification  \
# 0                              f                                f
# 1                              f                                f
# 2                              f                                f
# 3                              t                                f
# 4                              f                                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              1                                           1
# 2                              2                                           2
# 3                              2                                           1
# 4                              1                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.37
# 1                                           0              1.32
# 2                                           0              0.52
# 3                                           0              0.79
# 4                                           0               NaN
#
# [5 rows x 92 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
listings_df[[
    'id', 'name', 'summary', 'space', 'description', 'cancellation_policy',
    'host_has_profile_pic'
]]
# Out:
#              id                                           name  \
# 0         36720            Beautiful 2 rooms flat, Glockenbach
# 1         97945               Deluxw-Apartm. with roof terrace
# 2        114695             Apartment Munich/East with sundeck
# 3        127383              City apartment next to Pinakothek
# 4        157808                    Near Olympia,English Garden
# ...         ...                                            ...
# 11476  40342200  Charmante Altbauwohnung im Herzen von München
# 11477  40343877             Central apartment near the Bavaria
# 11478  40344151                                   Room in Laim
# 11479  40347084          Neuhausen mit persönlichem Ambiente !
# 11480  40354205             Private Room Historic Heart Munich
#
#                                                  summary  \
# 0      Very quiet, yet centrally located 2 rooms apt....
# 1                                                    NaN
# 2                                                    NaN
# 3      Die Wohnung hat 55 qm und ist voll ausgestatte...
# 4      Kleines gemütliches Privat Zimmer mit Kabel TV...
# ...                                                  ...
# 11476  Sehr charmante, helle Altbauwohnung im Herzen ...
# 11477  Big living room with large living room table, ...
# 11478  The apartment is in Laim. Bus stop and a tram ...
# 11479  Sie sind eingeladen, meine Wohnung (wunderbar ...
# 11480  Private room in newly renovated 3-bdr loft in ...
#
#                                                    space  \
# 0      2-Zimmer Altbauwohung Beste Lage, zentral, im ...
# 1      We offer a modern, quiet apartment with a sunn...
# 2      It´s a quiet and sunny apartment close to the ...
# 3      My cosy apartment is located in the heart of M...
# 4      Kleines gemütliches Privat Zimmer ca.14qm möbl...
# ...                                                  ...
# 11476                                                NaN
# 11477                                                NaN
# 11478                                                NaN
# 11479                                                NaN
# 11480  Beautifully decorated this loft excites with a...
#
#                                              description  \
# 0      Very quiet, yet centrally located 2 rooms apt....
# 1      We offer a modern, quiet apartment with a sunn...
# 2      It´s a quiet and sunny apartment close to the ...
# 3      My cosy apartment is located in the heart of M...
# 4      Kleines gemütliches Privat Zimmer ca.14qm möbl...
# ...                                                  ...
# 11476  Sehr charmante, helle Altbauwohnung im Herzen ...
# 11477  Big living room with large living room table, ...
# 11478  The apartment is in Laim. Bus stop and a tram ...
# 11479  Sie sind eingeladen, meine Wohnung (wunderbar ...
# 11480  Private room in newly renovated 3-bdr loft in ...
#
#                cancellation_policy host_has_profile_pic
# 0      strict_14_with_grace_period                    t
# 1                         flexible                    t
# 2      strict_14_with_grace_period                  NaN
# 3                         flexible                    t
# 4                         moderate                    t
# ...                            ...                  ...
# 11476                     moderate                    t
# 11477                     flexible                    t
# 11478                     flexible                    t
# 11479                     moderate                    t
# 11480  strict_14_with_grace_period                    t
#
# [11481 rows x 7 columns]

# %%
listings_selected_cols = listings_df[['id', 'name', 'summary', 'space', 'description', 'cancellation_policy', 'host_has_profile_pic',
            'host_is_superhost', 'host_total_listings_count', 'neighbourhood_cleansed', 'latitude', 'longitude' ,
            'property_type', 'room_type', 'accommodates', 'bedrooms', 'bathrooms', 'beds' ,'bed_type', 'amenities',
            'price', 'cleaning_fee' ,'review_scores_rating','cancellation_policy', 'reviews_per_month' ]]

# %% [markdown]
# # Data Cleaning
# * Change Prices to numeric

# %%
listings_selected_cols
# Out:
#              id                                           name  \
# 0         36720            Beautiful 2 rooms flat, Glockenbach
# 1         97945               Deluxw-Apartm. with roof terrace
# 2        114695             Apartment Munich/East with sundeck
# 3        127383              City apartment next to Pinakothek
# 4        157808                    Near Olympia,English Garden
# ...         ...                                            ...
# 11476  40342200  Charmante Altbauwohnung im Herzen von München
# 11477  40343877             Central apartment near the Bavaria
# 11478  40344151                                   Room in Laim
# 11479  40347084          Neuhausen mit persönlichem Ambiente !
# 11480  40354205             Private Room Historic Heart Munich
#
#                                                  summary  \
# 0      Very quiet, yet centrally located 2 rooms apt....
# 1                                                    NaN
# 2                                                    NaN
# 3      Die Wohnung hat 55 qm und ist voll ausgestatte...
# 4      Kleines gemütliches Privat Zimmer mit Kabel TV...
# ...                                                  ...
# 11476  Sehr charmante, helle Altbauwohnung im Herzen ...
# 11477  Big living room with large living room table, ...
# 11478  The apartment is in Laim. Bus stop and a tram ...
# 11479  Sie sind eingeladen, meine Wohnung (wunderbar ...
# 11480  Private room in newly renovated 3-bdr loft in ...
#
#                                                    space  \
# 0      2-Zimmer Altbauwohung Beste Lage, zentral, im ...
# 1      We offer a modern, quiet apartment with a sunn...
# 2      It´s a quiet and sunny apartment close to the ...
# 3      My cosy apartment is located in the heart of M...
# 4      Kleines gemütliches Privat Zimmer ca.14qm möbl...
# ...                                                  ...
# 11476                                                NaN
# 11477                                                NaN
# 11478                                                NaN
# 11479                                                NaN
# 11480  Beautifully decorated this loft excites with a...
#
#                                              description  \
# 0      Very quiet, yet centrally located 2 rooms apt....
# 1      We offer a modern, quiet apartment with a sunn...
# 2      It´s a quiet and sunny apartment close to the ...
# 3      My cosy apartment is located in the heart of M...
# 4      Kleines gemütliches Privat Zimmer ca.14qm möbl...
# ...                                                  ...
# 11476  Sehr charmante, helle Altbauwohnung im Herzen ...
# 11477  Big living room with large living room table, ...
# 11478  The apartment is in Laim. Bus stop and a tram ...
# 11479  Sie sind eingeladen, meine Wohnung (wunderbar ...
# 11480  Private room in newly renovated 3-bdr loft in ...
#
#                cancellation_policy host_has_profile_pic host_is_superhost  \
# 0      strict_14_with_grace_period                    t                 f
# 1                         flexible                    t                 t
# 2      strict_14_with_grace_period                  NaN               NaN
# 3                         flexible                    t                 t
# 4                         moderate                    t                 f
# ...                            ...                  ...               ...
# 11476                     moderate                    t                 f
# 11477                     flexible                    t                 f
# 11478                     flexible                    t                 f
# 11479                     moderate                    t                 f
# 11480  strict_14_with_grace_period                    t                 t
#
#        host_total_listings_count        neighbourhood_cleansed  latitude  \
# 0                            1.0  Ludwigsvorstadt-Isarvorstadt  48.13057
# 1                            1.0                        Hadern  48.11476
# 2                            NaN                  Berg am Laim  48.11923
# 3                            2.0                   Maxvorstadt  48.15198
# 4                            0.0                Schwabing-West  48.16381
# ...                          ...                           ...       ...
# 11476                        0.0         Neuhausen-Nymphenburg  48.14833
# 11477                        3.0                      Sendling  48.12343
# 11478                        0.0                          Laim  48.13829
# 11479                        0.0         Neuhausen-Nymphenburg  48.14794
# 11480                        7.0                Altstadt-Lehel  48.13819
#
#        longitude property_type        room_type  accommodates  bedrooms  \
# 0       11.56929     Apartment  Entire home/apt             2       1.0
# 1       11.48782     Apartment  Entire home/apt             2       1.0
# 2       11.63726     Apartment  Entire home/apt             5       1.0
# 3       11.56486     Apartment  Entire home/apt             4       1.0
# 4       11.56089     Apartment     Private room             2       1.0
# ...          ...           ...              ...           ...       ...
# 11476   11.54345     Apartment  Entire home/apt             2       1.0
# 11477   11.53969     Apartment     Private room             6       2.0
# 11478   11.51235     Apartment     Private room             2       1.0
# 11479   11.53698     Apartment  Entire home/apt             1       1.0
# 11480   11.57454          Loft     Private room             2       1.0
#
#        bathrooms  beds  bed_type  \
# 0            1.0   1.0     Futon
# 1            1.0   1.0  Real Bed
# 2            1.0   3.0  Real Bed
# 3            1.0   1.0  Real Bed
# 4            1.0   1.0  Real Bed
# ...          ...   ...       ...
# 11476        1.0   1.0  Real Bed
# 11477        2.0   5.0  Real Bed
# 11478        1.0   1.0  Real Bed
# 11479        1.0   NaN  Real Bed
# 11480        1.0   0.0  Real Bed
#
#                                                amenities    price  \
# 0      {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...   $95.00
# 1      {TV,"Cable TV",Wifi,Kitchen,"Free street parki...   $80.00
# 2      {TV,"Cable TV",Internet,Wifi,Kitchen,"Free str...   $95.00
# 3      {TV,"Cable TV",Wifi,Kitchen,"Pets allowed",Bre...  $120.00
# 4      {TV,"Cable TV",Internet,Wifi,"Wheelchair acces...   $35.00
# ...                                                  ...      ...
# 11476  {Kitchen,Heating,"Smoke detector",Essentials,S...   $80.00
# 11477  {TV,Wifi,Kitchen,"Free parking on premises",El...  $180.00
# 11478  {Wifi,Kitchen,Heating,"Smoke detector",Essenti...   $30.00
# 11479  {TV,Wifi,Kitchen,Breakfast,Elevator,Heating,Wa...   $40.00
# 11480  {TV,Wifi,Kitchen,"Indoor fireplace",Heating,"S...   $60.00
#
#       cleaning_fee  review_scores_rating          cancellation_policy  \
# 0           $30.00                  98.0  strict_14_with_grace_period
# 1           $10.00                  97.0                     flexible
# 2           $60.00                  95.0  strict_14_with_grace_period
# 3           $28.00                  97.0                     flexible
# 4           $10.00                   NaN                     moderate
# ...            ...                   ...                          ...
# 11476          NaN                   NaN                     moderate
# 11477       $80.00                   NaN                     flexible
# 11478          NaN                   NaN                     flexible
# 11479          NaN                   NaN                     moderate
# 11480          NaN                   NaN  strict_14_with_grace_period
#
#        reviews_per_month
# 0                   0.37
# 1                   1.32
# 2                   0.52
# 3                   0.79
# 4                    NaN
# ...                  ...
# 11476                NaN
# 11477                NaN
# 11478                NaN
# 11479                NaN
# 11480                NaN
#
# [11481 rows x 25 columns]

# %% [markdown]
# # Broad overview of what to do
#
# 1. Relationship of price and neighbourhood, room characteristics(i.e. property type, bedrooms, amenities etc.) and reviews
# 2. Calculate weighted review
# 3. Relationship of host is superhost with reviews or price
# 4. Effect of Cancellation policy on bookings
